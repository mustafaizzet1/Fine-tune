# %% [markdown]
# <a href="https://colab.research.google.com/github/mustafaizzet1/Fine-tune/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install unsloth

# %%
pip install datasets trl bitsandbytes peft accelerate

# %%
from unsloth import FastLanguageModel

model_name = "unsloth/Meta-Llama-3.1-8B"
max_seq_length = 2048
load_in_4bit = True  # T4 için ideal

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = model_name,
    max_seq_length = max_seq_length,
    dtype = None,
    load_in_4bit = load_in_4bit,
)
# Out:
# ==((====))==  Unsloth 2025.5.6: Fast Llama patching. Transformers: 4.51.3.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.7.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.3.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.30. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.96G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/235 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/459 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]

# %%
from datasets import load_dataset

alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer.eos_token # Must add EOS_TOKEN
def formatting_prompts_func(examples):
    instructions = examples["instruction"]
    inputs       = examples["input"]
    outputs      = examples["output"]
    texts = []
    for instruction, input, output in zip(instructions, inputs, outputs):
        # Must add EOS_TOKEN, otherwise your generation will go on forever!
        text = alpaca_prompt.format(instruction, input, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }
pass



dataset = load_dataset("json", data_files="/content/alpaca_formatveri.jsonl", split="train")

dataset = dataset.map(formatting_prompts_func, batched = True,)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/21242 [00:00<?, ? examples/s]

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth 2025.5.6 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %%
from pprint import pprint
pprint(dataset[0])
# Out:
# {'input': 'Bir patentin yenilik ve buluş basamağı kriterlerini taşımadığı '
#           'durumlarda ne gibi hukuki sonuçlar doğar?',
#  'instruction': 'Aşağıdaki soruyu yanıtlayın.',
#  'output': 'Bir patentin yenilik ve buluş basamağı kriterlerini taşımadığı '
#            'tespit edilirse, bu patentin hükümsüzlüğüne karar verilebilir. '
#            'Hükümsüzlük kararı, patentin tescilinin iptalini ve sicilden '
#            'terkinini gerektirir. Bu durumda, ilgili patentin daha önceki '
#            'başvurularla veya bilinen tekniklerle örtüşmesi gibi sebeplerle '
#            'geçerliliği sorgulanabilir.',
#  'text': 'Below is an instruction that describes a task, paired with an input '
#          'that provides further context. Write a response that appropriately '
#          'completes the request.\n'
#          '\n'
#          '### Instruction:\n'
#          'Aşağıdaki soruyu yanıtlayın.\n'
#          '\n'
#          '### Input:\n'
# ...

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False, # Can make training 5x faster for short sequences.
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        # num_train_epochs = 1, # Set this for 1 full training run.
        max_steps = 60,
        learning_rate = 2e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "8Bll",
        report_to = "wandb", # Use this for WandB etc
    ),
)
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=2):   0%|          | 0/21242 [00:00<?, ? examples/s]

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 21,242 | Num Epochs = 1 | Total steps = 60
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 41,943,040/8,000,000,000 (0.52% trained)
#     <div>
#
#       <progress value='45' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [45/60 04:35 < 01:35, 0.16 it/s, Epoch 0.02/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.226800</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.926100</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.041100</td>
#     </tr>
#     <tr>
#       <td>4</td>
# ...

# %%
model.save_pretrained("lora_model")  # Local saving
tokenizer.save_pretrained("lora_model")
# model.push_to_hub("your_name/lora_model", token = "...") # Online saving
# tokenizer.push_to_hub("your_name/lora_model", token = "...") # Online saving
# Out:
# ('lora_model/tokenizer_config.json',
#  'lora_model/special_tokens_map.json',
#  'lora_model/tokenizer.json')

# %%
if False:
    from unsloth import FastLanguageModel
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        max_seq_length = max_seq_length,
        dtype = dtype,
        load_in_4bit = load_in_4bit,
    )
    FastLanguageModel.for_inference(model) # Enable native 2x faster inference

# alpaca_prompt = You MUST copy from above!

inputs = tokenizer(
[
    alpaca_prompt.format(
        "başka birinin üzerine tescilli tasarımı şirketimde kullanırsam birşey olur mu?", # instruction
        "", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 128)
# Out:
# <|begin_of_text|>Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# başka birinin üzerine tescilli tasarımı şirketimde kullanırsam birşey olur mu?
#
# ### Input:
#
#
# ### Response:
# Fikri mülkiyet hakları çerçevesinde, başka bir markanın tescilli tasarımı üzerinde tescilli tasarımı kullanmak, bu tasarımın korunması açısından önemli bir durum oluşturur. Bu durum, tasarımın ayırt ediciliği ve tanınmışlığı açısından değerlendirilmelidir. Eğer tasarımın ayırt ediciliği ve tanınmışlığı ispatlanmışsa, başka bir markanın kullanımına karşı hukuki yollara başvurmak mümkündür.<|end_of_text|>
